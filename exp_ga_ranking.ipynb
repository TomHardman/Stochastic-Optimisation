# %%
from ga import geneticalgorithm as ga
from ga import run_multiple
import matplotlib.pyplot as plt
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'ranking_based_roulette',
            'selection_pressure': 1.4}

opt_arr_rr, res_arr_rr = run_multiple(50, algo_param, 8)
opt_values_rr = [opt_arr_rr[i]['function'] for i in range(len(opt_arr_rr))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'ranking_based_roulette',
            'selection_pressure': 1.8}

opt_arr_rr_18, res_arr_rr_18 = run_multiple(50, algo_param, 8)
opt_values_rr_18 = [opt_arr_rr_18[i]['function'] for i in range(len(opt_arr_rr))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'ranking_based_roulette',
            'selection_pressure': 2}

opt_arr_rr_2, res_arr_rr_2 = run_multiple(50, algo_param, 8)
opt_values_rr_2 = [opt_arr_rr_2[i]['function'] for i in range(len(opt_arr_rr))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'ranking_based_roulette',
            'selection_pressure': 1.6}

opt_arr_rr_16, res_arr_rr_16 = run_multiple(50, algo_param, 8)
opt_values_rr_16 = [opt_arr_rr_16[i]['function'] for i in range(len(opt_arr_rr))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'ranking_based_roulette',
            'selection_pressure': 1.7}

opt_arr_rr_17, res_arr_rr_17 = run_multiple(50, algo_param, 8)
opt_values_rr_17 = [opt_arr_rr_17[i]['function'] for i in range(len(opt_arr_rr))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'ranking_based_roulette',
            'selection_pressure': 1.2}

opt_arr_rr_12, res_arr_rr_12 = run_multiple(50, algo_param, 8)
opt_values_rr_12 = [opt_arr_rr_12[i]['function'] for i in range(len(opt_arr_rr))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'ranking_based_roulette',
            'selection_pressure': 1}

opt_arr_rr_1, res_arr_rr_1 = run_multiple(50, algo_param, 8)
opt_values_rr_1 = [opt_arr_rr_1[i]['function'] for i in range(len(opt_arr_rr))]

# %%
fig, ax = plt.subplots()
data_list = [opt_values_rr_1, opt_values_rr_12, opt_values_rr, opt_values_rr_16, opt_values_rr_17, 
             opt_values_rr_18, opt_values_rr_2]
label_list = ['Ranking Based Roulette, S=1', 'Ranking Based Roulette, S=1.2', 'Ranking Based Roulette, S=1.4', 'Ranking Based Roulette, S=1.6', 
              'Ranking Based Roulette, S=1.7', 'Ranking Based Roulette, S=1.8', 'Ranking Based Roulette, S=2']

ax.boxplot(data_list, vert=False, patch_artist=True, labels=label_list, whis=2)
plt.show()
