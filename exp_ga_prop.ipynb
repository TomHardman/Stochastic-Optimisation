# %%
from ga import geneticalgorithm as ga
from ga import run_multiple
import matplotlib.pyplot as plt
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'proportional_roulette',
            'selection_pressure': 1.4,
            'offset': 1}

opt_arr_pr_1, res_arr_pr_1 = run_multiple(50, algo_param, 8)
opt_values_pr_1 = [opt_arr_pr_1[i]['function'] for i in range(len(opt_arr_pr_1))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'proportional_roulette',
            'selection_pressure': 1.4,
            'offset': 10}

opt_arr_pr_10, res_arr_pr_10 = run_multiple(50, algo_param, 8)
opt_values_pr_10 = [opt_arr_pr_10[i]['function'] for i in range(len(opt_arr_pr_10))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'proportional_roulette',
            'selection_pressure': 1.4,
            'offset': 0.5}

opt_arr_pr_05, res_arr_pr_05 = run_multiple(50, algo_param, 8)
opt_values_pr_05 = [opt_arr_pr_05[i]['function'] for i in range(len(opt_arr_pr_10))]

# %%
algo_param={'max_num_iteration': 10000,
            'population_size':80,
            'mutation_probability':0.01,
            'elit_ratio': 0.0,
            'crossover_probability': 0.45,
            'parents_portion': 0.3,
            'crossover_type':'uniform',
            'max_iteration_without_improv':None,
            'selection_method': 'proportional_roulette',
            'selection_pressure': 1.4,
            'offset': 0.2}

opt_arr_pr_02, res_arr_pr_02 = run_multiple(50, algo_param, 8)
opt_values_pr_02 = [opt_arr_pr_02[i]['function'] for i in range(len(opt_arr_pr_02))]
# Out:
# [0.43441176 0.3468375  0.33000633 0.3287541  0.32518175 0.32373878
#  0.321385   0.32065616 0.31914657 0.31874762 0.31305473 0.31239759
#  0.31139878 0.31076795 0.31050294 0.30905411 0.30758036 0.30477228
#  0.30192256 0.30175684 0.30157565 0.29837012 0.29824594 0.29713786
#  0.29660838 0.29216876 0.2917678  0.29074452 0.28979529 0.28964269
#  0.28926758 0.28667401 0.28625184 0.28523982 0.28504537 0.28503034
#  0.28459619 0.28394323 0.28385111 0.28205573 0.28080886 0.27900646
#  0.27750775 0.27570682 0.2716381  0.2711204  0.269439   0.26758026
#  0.26729354 0.26649503 0.26600924 0.26579943 0.26428782 0.26075985
#  0.26052463 0.25956495 0.25885757 0.25826151 0.25735546 0.25678458
#  0.25533279 0.25518509 0.25104476 0.25041453 0.24886968 0.24884646
#  0.24832292 0.24814019 0.24797388 0.24733375 0.24710684 0.24513389
#  0.24445485 0.24410661 0.24362014 0.24330729 0.24304785 0.23280425
#  0.2251686  0.2       ]
# [0.39067258 0.35013882 0.34711906 0.32464176 0.32373878 0.31914657
# ...

# %%
fig, ax = plt.subplots()
data_list = [opt_values_pr_05, opt_values_pr_1, opt_values_pr_10]
label_list = ['Proportional Roulette, Offset=0.5', 'Proportional Roulette, Offset = 1', 'Proportional Roulette, Offset = 10',]

ax.boxplot(data_list, vert=False, patch_artist=True, labels=label_list, whis=2)
plt.show()
