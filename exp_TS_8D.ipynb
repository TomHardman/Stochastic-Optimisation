# %%
from TS import run_multiple_ts, grid_search_alpha_delta0
from util import keanes_bump_ts
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
alpha_arr = [0.9, 0.92, 0.95, 0.97, 0.99]
delta0_arr = [0.5, 1, 2, 3]
n_cells = 2
alpha_mesh2, delta_mesh2, means2 = grid_search_alpha_delta0(alpha_arr, delta0_arr, n_cells, D=8, log=True)
# Out:
# Starting for alpha=0.9, delta_0=0.5
# Starting for alpha=0.9, delta_0=1
# Starting for alpha=0.9, delta_0=2
# Starting for alpha=0.9, delta_0=3
# Starting for alpha=0.92, delta_0=0.5
# Starting for alpha=0.92, delta_0=1
# Starting for alpha=0.92, delta_0=2
# Starting for alpha=0.92, delta_0=3
# Starting for alpha=0.95, delta_0=0.5
# Starting for alpha=0.95, delta_0=1
# Starting for alpha=0.95, delta_0=2
# Starting for alpha=0.95, delta_0=3
# Starting for alpha=0.97, delta_0=0.5
# Starting for alpha=0.97, delta_0=1
# Starting for alpha=0.97, delta_0=2
# Starting for alpha=0.97, delta_0=3
# Starting for alpha=0.99, delta_0=0.5
# Starting for alpha=0.99, delta_0=1
# Starting for alpha=0.99, delta_0=2
# Starting for alpha=0.99, delta_0=3

# %%
hm = sns.heatmap(means2, cmap='viridis', xticklabels=[0.5, 1, 2, 3], yticklabels=[0.9, 0.92, 0.95, 0.97, 0.99], annot=True, fmt='.3f')
hm.set(title='Grid search on {} and {}$_0$ for n_cells=2'.format(chr(945),chr(948)), ylabel=chr(945), xlabel=chr(948)+'$_0$')
# Out:
# [Text(0.5, 1.0, 'Grid search on α and δ$_0$ for n_cells=2'),
#  Text(50.722222222222214, 0.5, 'α'),
#  Text(0.5, 23.52222222222222, 'δ$_0$')]

# %%
alpha_arr = [0.9, 0.92, 0.95, 0.97, 0.99]
delta0_arr = [0.5, 1, 2, 3]
n_cells = 3
alpha_arr3, delta_arr3, means3 = grid_search_alpha_delta0(alpha_arr, delta0_arr, n_cells, D=8, log=True)
# Out:
# Starting for alpha=0.9, delta_0=0.5
# Starting for alpha=0.9, delta_0=1
# Starting for alpha=0.9, delta_0=2
# Starting for alpha=0.9, delta_0=3
# Starting for alpha=0.92, delta_0=0.5
# Starting for alpha=0.92, delta_0=1
# Starting for alpha=0.92, delta_0=2
# Starting for alpha=0.92, delta_0=3
# Starting for alpha=0.95, delta_0=0.5
# Starting for alpha=0.95, delta_0=1
# Starting for alpha=0.95, delta_0=2
# Starting for alpha=0.95, delta_0=3
# Starting for alpha=0.97, delta_0=0.5
# Starting for alpha=0.97, delta_0=1
# Starting for alpha=0.97, delta_0=2
# Starting for alpha=0.97, delta_0=3
# Starting for alpha=0.99, delta_0=0.5
# Starting for alpha=0.99, delta_0=1
# Starting for alpha=0.99, delta_0=2
# Starting for alpha=0.99, delta_0=3

# %%
hm = sns.heatmap(means3, cmap='viridis', xticklabels=delta_arr3, yticklabels=alpha_arr3, annot=True, fmt='.3f')
hm.set(title='Grid search on {} and {}$_0$ for n_cells=3'.format(chr(945),chr(948)), ylabel=chr(945), xlabel=chr(948)+'$_0$')
# Out:
# [Text(0.5, 1.0, 'Grid search on α and δ$_0$ for n_cells=3'),
#  Text(50.722222222222214, 0.5, 'α'),
#  Text(0.5, 23.52222222222222, 'δ$_0$')]

# %%
alpha_arr = [0.75, 0.8, 0.85, 0.9]
delta0_arr = [3, 4, 5]
n_cells = 3
alpha_arr3_2, delta_arr3_2, means3_2 = grid_search_alpha_delta0(alpha_arr, delta0_arr, n_cells, D=8, log=True)
# Out:
# Starting for alpha=0.75, delta_0=3
# Starting for alpha=0.75, delta_0=4
# Starting for alpha=0.75, delta_0=5
# Starting for alpha=0.8, delta_0=3
# Starting for alpha=0.8, delta_0=4
# Starting for alpha=0.8, delta_0=5
# Starting for alpha=0.85, delta_0=3
# Starting for alpha=0.85, delta_0=4
# Starting for alpha=0.85, delta_0=5
# Starting for alpha=0.9, delta_0=3
# Starting for alpha=0.9, delta_0=4
# Starting for alpha=0.9, delta_0=5

# %%
hm = sns.heatmap(means3_2, cmap='viridis', xticklabels=delta_arr3_2, yticklabels=alpha_arr3_2, annot=True, fmt='.3f')
hm.set(title='Grid search on {} and {}$_0$ for n_cells=3'.format(chr(945),chr(948)), ylabel=chr(945), xlabel=chr(948)+'$_0$')
# Out:
# [Text(0.5, 1.0, 'Grid search on α and δ$_0$ for n_cells=3'),
#  Text(0.5, 23.52222222222222, 'α'),
#  Text(50.722222222222214, 0.5, 'δ$_0$')]

# %%
alpha_arr = [0.75, 0.8, 0.85, 0.9]
delta0_arr = [3, 4, 5]
n_cells = 2
alpha_arr2_2, delta_arr2_2, means2_2 = grid_search_alpha_delta0(alpha_arr, delta0_arr, n_cells, D=8, log=True)
# Out:
# Starting for alpha=0.75, delta_0=3
# Starting for alpha=0.75, delta_0=4
# Starting for alpha=0.75, delta_0=5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 4
#       2 delta0_arr = [3, 4, 5]
#       3 n_cells = 2
# ----> 4 alpha_arr2_2, delta_arr2_2, means2_2 = grid_search_alpha_delta0(alpha_arr, delta0_arr, n_cells, D=8, log=True)
#
# File ~/Documents/Engineering/Year 4/4M17/CW2/TS.py:407, in grid_search_alpha_delta0(alpha_arr, delta0_arr, n_cells, D, log)
#     393     print('Starting for alpha={}, delta_0={}'.format(alpha, delta0))
#     395 algo_param  = {'search_method': 'exhaustive',
#     396                 'N': 7,
#     397                 'M': 4,
#    (...)
#     404                 'reduce_factor': alpha,
#     405                 'n_cells': n_cells}
# --> 407 best_arr = run_multiple_ts(50, f, D, algo_param, log=False)
# ...

# %%
hm = sns.heatmap(means2_2, cmap='viridis', xticklabels=delta_arr2_2, yticklabels=alpha_arr2_2, annot=True, fmt='.3f')
hm.set(title='Grid search on {} and {}$_0$ for n_cells=2'.format(chr(945),chr(948)), ylabel=chr(945), xlabel=chr(948)+'$_0$')
# Out:
# [Text(0.5, 1.0, 'Grid search on α and δ$_0$ for n_cells=2'),
#  Text(0.5, 23.52222222222222, 'α'),
#  Text(50.722222222222214, 0.5, 'δ$_0$')]

# %%
means2_2
# Out:
# array([[0.64719345, 0.64986204, 0.65142261],
#        [0.64911213, 0.64592327, 0.65925989],
#        [0.66028378, 0.64882417, 0.64824683]])

# %%
means3_2
# Out:
# array([[0.64105111, 0.64966329, 0.65592362],
#        [0.64363395, 0.65553392, 0.66008397],
#        [0.64915327, 0.65251227, 0.6552495 ],
#        [0.65908701, 0.64226878, 0.65145463]])
